# %%
from collections import Counter

import numpy as np
import tensorflow as tf
from tensorflow.contrib import rnn
from sklearn.model_selection import train_test_split
from utils import SentenceReader
from gensim.models import Word2Vec

# %%
def build_dictionary(words):
    counter = Counter(words)
    dictionary = dict()
    for word, _ in counter.most_common(10000):
        dictionary[word] = len(dictionary)
    reverse_dict = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dict


def read_data(dir_name):
    sentences = list(SentenceReader('data/shakespear/'))
    content = []
    for s in sentences:
        content.extend(s)
    content = np.reshape(content, [-1, ])
    model = Word2Vec(sentences, size=w2v_size, min_count=1)
    print(content, content.shape)
    return content, model


def get_trainable_data(word_series, dictionary, sequence_size, w2v_model):
    m = len(word_series)-sequence_size+1
    data = np.zeros((m, sequence_size, w2v_size))
    for i in range(m):
        for j in range(sequence_size):
            word = word_series[i+j]
            data[i, j] = w2v_model[word]
    return data


def get_data(sequence_size):
    raw, w2v_model = read_data('belling_the_cat.txt')
    dictionary, reverse_dictionary = build_dictionary(raw)
    data = get_trainable_data(raw, dictionary, sequence_size, w2v_model)
    return dictionary, reverse_dictionary, data, w2v_model


def word_to_vector(word, dictionary):
    vector = np.zeros(len(dictionary))
    idx = int(dictionary[word])
    vector[idx] = 1
    return vector


def vector_to_word(vector, reverse_dictionary):
    index = vector.argmax()
    return reverse_dictionary[index]


def get_training_and_test_data_from_sequences(word_sequence_matrix, dictionary_size, test_size=0.1):
    """Given a sequence of word indexes"""
    x = word_sequence_matrix[:, :-1, :]
    y = word_sequence_matrix[:, -1, :]
    # x = x.reshape([-1, x.shape[1], 1])
    return train_test_split(x, y, test_size=test_size, random_state=1211)


def represent_x_and_y(x, y):
    y_args = y.argsort(1)[:, -3:][:,::-1]
    for i in range(x.shape[0]):
        inputs = [rev_dict[j.argmax()] for j in x[i]]
        output = [rev_dict[j] for j in y_args[i]]
        outputs_with_score = y[i][y_args[i]]
        print(' '.join(inputs), output, outputs_with_score)

# %% [markdown]
# ## Define parameters.

# %%
n_input = 3
max_iter = 1000
w2v_size = 100

# %% [markdown]
# ## Let's prepare our data set for training and validation.

# %%
dictionary, rev_dict, word_sequences, w2v_model = get_data(n_input+1)
vocab_size = len(dictionary)
x_train, x_test, y_train, y_test = get_training_and_test_data_from_sequences(word_sequences, vocab_size)
# Out:
# ['suffolk' ':' 'he' ..., 'up' '.' "'"] (23229,)

# %% [markdown]
# ## Tensorflow setup.

# %%
n_hidden = 50
learning_rate = 0.001

# %%
tf.reset_default_graph()

x = tf.placeholder('float', (None, n_input, w2v_size), name='x')
y = tf.placeholder('float', (None, w2v_size), name='y')

weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, w2v_size]), name='weights_out')
}
biases = {
    'out': tf.Variable(tf.random_normal([w2v_size]), name='biases_out')
}

def RNN(x, w, b):
    x = tf.unstack(x, n_input, 1)
    rnn_cell = stacked_lstm = tf.contrib.rnn.MultiRNNCell([rnn.BasicLSTMCell(n_hidden) for _ in range(2)])
    output, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)
    return tf.matmul(output[-1], w['out']) + b['out']

model = RNN(x, weights, biases)
prediction = tf.nn.softmax(model)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=model, labels=y))
optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

init = tf.global_variables_initializer()

def train(session, batch_size, epochs):
    m = x_train.shape[0]
    for e in range(epochs):
        for i in range(0, m, batch_size):
            x_batch = x_train[i:i+batch_size, :]
            y_batch = y_train[i:i+batch_size, :]
            session.run(optimizer, feed_dict={x: x_batch, y: y_batch})
        c = session.run(cost, feed_dict={x: x_test, y:y_test})
        print('{}. Cost - {}'.format(e, c))

def predict(session, x_test):
    return session.run(prediction, feed_dict={x: x_test})

# %%
session.close()
session = tf.Session()
session.run(init)
train(session, 500, 50)
predictions = predict(session, x_test)
# Out:
# 0. Cost - -32.637779235839844
# 1. Cost - -144.29051208496094
# 2. Cost - -214.3891143798828
# 3. Cost - -258.60205078125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-f22d4944fac7> in <module>()
#       2 session = tf.Session()
#       3 session.run(init)
# ----> 4 train(session, 500, 50)
#       5 predictions = predict(session, x_test)
#
# <ipython-input-61-2066f4d785ad> in train(session, batch_size, epochs)
#      30             x_batch = x_train[i:i+batch_size, :]
#      31             y_batch = y_train[i:i+batch_size, :]
# ---> 32             session.run(optimizer, feed_dict={x: x_batch, y: y_batch})
#      33         c = session.run(cost, feed_dict={x: x_test, y:y_test})
#      34         print('{}. Cost - {}'.format(e, c))
#
# /home/alok/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/alok/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/alok/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/alok/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/alok/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# [rev_dict[i] for i in predictions.argmax(1)]
# predictions.argsort(1)[:, :3]
represent_x_and_y(x_test, predictions)
# Out:
# : my best ['of', 'must', 'be'] [ 0.11740546  0.05834505  0.05280576]
# , And in ['the', 'she', 'a'] [ 0.15624152  0.11795139  0.08184648]
# Olland to her ['her', 'to', '.'] [  9.85010684e-01   8.95102974e-03   5.88946510e-04]
# And such a ['whole', 'Murder', 'desire'] [ 0.05321015  0.04727762  0.04624144]
# asleep . MERCUTIO ['I', ',', ':'] [ 0.97975791  0.00319734  0.00300873]
# never kill ' ['d', 'Twill', 'learning'] [ 0.58107132  0.06078913  0.052454  ]
# sir : I ['must', 'be', 'was'] [ 0.57835841  0.13475895  0.03974489]
# heart , Yet ["'", 'you', 'I'] [ 0.23718159  0.1846723   0.15584044]
# it is , ['And', "'", 'that'] [ 0.0896019   0.07031361  0.06757016]
# , villain , ['I', 'the', 'To'] [ 0.4140583   0.19063208  0.06067153]
# appear now ! ['Is', 'goodly', 'if'] [ 0.19148324  0.09862468  0.09764537]
# itself . You ['all', 'You', ','] [ 0.35888061  0.19117349  0.0279025 ]
# , but this ['I', "'", 'shall'] [ 0.21739744  0.07227439  0.05873606]
# eyes , you ['a', 'are', 'imperial'] [ 0.21844831  0.08025374  0.0787507 ]
# ' s lose ['it', 'the', 'a'] [ 0.27903026  0.09739224  0.0702645 ]
# shall his wife [',', 'good', 'in'] [ 0.28547376  0.05626637  0.05558304]
# short to drunk [',', 'my', 'it'] [ 0.3272441   0.24899739  0.07366177]
# thou hast not ['not', 'a', ':'] [ 0.39593515  0.29021043  0.10942744]
# that daylight but ['but', 'my', 'know'] [ 0.97274649  0.00760412  0.00231996]
# patroclus . SPEED ['.', 'SPEED', 'Come'] [ 0.76578194  0.10074624  0.03927399]
# shall not died [',', '.', ':'] [ 0.64131874  0.06566177  0.04254489]
# ' d in ['the', 'this', 'his'] [ 0.22020823  0.08573617  0.05969986]
# to Coriolanus . ['French', '.', 'PAROLLES'] [ 0.57967013  0.22599418  0.0309472 ]
# difference : And ['And', 'A', 'care'] [  9.95417356e-01   3.86419101e-03   1.66361948e-04]
# helling new and ['and', 'new', 'terror'] [  9.94911849e-01   2.20450084e-03   6.35676552e-04]
# me ; Yet ['I', 'you', 'then'] [ 0.12314269  0.10833487  0.06046853]
# sister ' s ['and', 'in', '!'] [ 0.34532851  0.15321317  0.1029931 ]
# coronation , or ['or', ':', 'Are'] [ 0.97333187  0.00310862  0.00155541]
# it nothing at ['well', 'all', 'As'] [ 0.63904554  0.04467487  0.0201053 ]
# As duty in ['in', 'thine', 'kingdom'] [ 0.3666386   0.28219458  0.11330627]
# Your steel and ['seem', 'and', 'evil'] [ 0.62750548  0.14283851  0.02152768]
# with her words [',', 'and', ';'] [ 0.52881134  0.05557354  0.04034913]
# man ! ANNE [':', 'I', 'our'] [ 0.70151496  0.05340971  0.02456938]
# what . Host ['me', ':', 'wouldst'] [ 0.13158847  0.06470087  0.06319591]
# , to hold ['it', 'your', ';'] [ 0.13156258  0.07651582  0.05376813]
# the noble hand ['So', 'with', 'is'] [ 0.31050926  0.12025303  0.09464215]
# heavier fates of ['of', 'fates', 'then'] [ 0.88376087  0.04797326  0.03265264]
# : Hasty with ['now', 'we', 'with'] [  9.97458160e-01   4.96372639e-04   4.70067811e-04]
# , thou ! ['a', "'", 'me'] [ 0.07722222  0.0368412   0.02632141]
# ages of the ['sacred', 'of', 'laughest'] [ 0.88692081  0.01498786  0.00737011]
# great out and ['fled', 'lay', 'follow'] [ 0.17425872  0.0847532   0.07278483]
# let us blame ['the', 'them', 'more'] [ 0.25363469  0.25322285  0.09618811]
# coxcomb? ACHILLES : ['ACHILLES', 'I', 'know'] [ 0.68458545  0.16496432  0.08375666]
# base as , ['thou', 'leawer', 'I'] [ 0.30105782  0.14136036  0.07733154]
# all of your ['banish', 'brets', 'wise'] [ 0.05458503  0.0372224   0.03040771]
# an exhibition not ['not', 'habit', 'find'] [ 0.82046008  0.08139607  0.00475557]
# , such a ['of', "'", 'naked'] [ 0.09095718  0.03819868  0.03792045]
# their men Flint ['of', 'Page', 'upon'] [ 0.07962737  0.04944296  0.04551818]
# did himself said ['Have', ':', 'If'] [ 0.43451566  0.40842295  0.03446005]
# promised my revenge ['revenge', 'lord', 'prove'] [ 0.46996745  0.11922447  0.04186609]
# hope ; God ['will', 'be', '!'] [ 0.21365862  0.20696953  0.153883  ]
# I ' ll ['not', 'speak', 'see'] [ 0.08312517  0.07008551  0.03019466]
# he not glad ['but', 'this', 'a'] [ 0.05874683  0.05458029  0.0474204 ]
# answered : Yet ['Yet', 'By', 'I'] [ 0.97149742  0.01783586  0.00150914]
# ' ll never ['you', 'my', 'the'] [ 0.1651745   0.16141419  0.03152657]
# all his oaths? ['that', 'men', "'"] [ 0.31491232  0.10443795  0.07009697]
# confident I stood ['stood', 'I', 'say'] [ 0.50241005  0.21066201  0.07092983]
# wish their hands ['hands', 'palms', 'As'] [ 0.46014556  0.15577103  0.08682798]
# such sweetly towers [',', 'of', 'The'] [ 0.60225612  0.08717594  0.0716374 ]
# ! Second Senator [':', 'Well', 'before'] [  9.96244848e-01   1.20155781e-03   5.14311017e-04]
# I do beseech ['you', ',', 'but'] [ 0.29196221  0.21720877  0.08051293]
# hear excellent words ['.', 'and', 'you'] [ 0.42476705  0.21123144  0.07137173]
# to - night [',', ':', ';'] [ 0.29657573  0.28948736  0.17197929]
# my death in ['this', 'But', 'a'] [ 0.25030404  0.11771496  0.05974864]
# That ' s ['a', 'the', 'I'] [ 0.08499555  0.07284205  0.03591258]
# day lie and [':', 'That', 'with'] [ 0.09346884  0.04845101  0.0480787 ]
# , but every ['shall', 'I', "'"] [ 0.07685839  0.05822777  0.04650112]
# is giddy one [';', 'earth', 'one'] [ 0.78450215  0.13548617  0.03592557]
# audient varlet . ['my', 'and', 'varlet'] [ 0.5206328   0.1486914   0.08004824]
# am of the ['very', 'hand', ';'] [ 0.12502757  0.05106495  0.04054892]
# will all humours [',', ':', '.'] [ 0.56724828  0.18407516  0.05042642]
# should lie , ['with', 'thou', 'BRUTUS'] [ 0.10919137  0.0992806   0.08834596]
# ; Most general ['What', 'of', ','] [ 0.29502505  0.16579102  0.1337626 ]
# boy and oaks ['and', 'they', 'Master'] [ 0.30057931  0.14950435  0.08613779]
# , then tell ['be', 'I', 'me'] [ 0.2607871   0.19676197  0.05831813]
# hope I was ['will', 'speak', 'love'] [ 0.17620216  0.14380474  0.06282918]
# in proper dismercise ['Other', "'", 'country'] [ 0.21536274  0.21049348  0.15341033]
# , I ' ['ll', 's', 'am'] [ 0.90954626  0.05879412  0.00279956]
# think who is ['as', "'", 'all'] [ 0.50343281  0.37465614  0.02306483]
# d thou slept ['my', 'me', ':'] [ 0.25901234  0.14524136  0.09382057]
# day ' s ['a', 'the', 'I'] [ 0.28346321  0.04668137  0.0443333 ]
# ctedious angel , ['But', 'I', 'there'] [ 0.45871261  0.43912026  0.01739765]
# : That thinkest [',', 'like', 'her'] [ 0.3003599   0.06302807  0.06201597]
# saw ' em [':', ',', 'give'] [ 0.503506    0.08546546  0.05356393]
# vineyards , Who ['I', ',', "'"] [ 0.17117359  0.13050103  0.08132149]
# feast Of this ['we', 'this', 'whom'] [ 0.5046975   0.22781324  0.12540266]
# despised , I ['I', 'do', 'am'] [ 0.97448766  0.00348177  0.0033496 ]
# BIRON : She ['She', 'will', ':'] [ 0.93944257  0.02002652  0.0129778 ]
# , but to ['I', 'the', 'morrow'] [ 0.21502341  0.12014753  0.03670933]
# our field ; ['I', 'thou', 'and'] [ 0.74638343  0.20150211  0.01239585]
# took upon That ['That', 'well', 'have'] [ 0.64715677  0.05124563  0.02763169]
# with a speed ['would', 'as', ','] [ 0.21909407  0.08992615  0.05732381]
# virtuous Scotland ! ['!', 'good', 'CAIUS'] [ 0.930664    0.03985281  0.0106428 ]
# aid there are ['are', 'show', 'well'] [ 0.13753387  0.08670376  0.08181261]
# out , And ['are', 'a', 'all'] [ 0.07689209  0.06183979  0.05250568]
# NORFOLK : We ['song', 'tell', 'show'] [ 0.31179896  0.18237893  0.13669287]
# his impeopleness an ['an', 'restore', 'OTHELLO'] [  9.76955950e-01   1.93210400e-03   8.68104980e-04]
# of your army ["'", 'to', '.'] [ 0.06518516  0.03004233  0.02418028]
# you from many ['her', '.', 'them'] [ 0.16442622  0.15404817  0.06690878]
# , If my ['heart', 'be', 'fit'] [ 0.03821775  0.03576764  0.03153149]
# , see my ['lord', 'her', 'I'] [ 0.05056393  0.0315406   0.02932086]
# mistress of France [';', 'we', ','] [ 0.2718668   0.26748604  0.14767615]
# love them , ['If', 'we', 'But'] [ 0.1449912   0.13253799  0.11616898]
# mock ' d ['d', "'", 'LADY'] [ 0.96708888  0.01109789  0.00519562]
# that time came ['in', 'are', 'I'] [ 0.1261366   0.10380048  0.090563  ]
# , if they ['my', 'may', 'have'] [ 0.13976365  0.07246619  0.04770087]
# city ' s ['I', 'the', 'as'] [ 0.49473572  0.29560083  0.03847723]
# saved , And ['And', ',', 'A'] [ 0.97319013  0.01490311  0.0015849 ]
# s seems , ['England', 'children', 'that'] [ 0.20712835  0.19554622  0.16257365]
# Basis I love ['love', 'to', 'a'] [  9.98761058e-01   2.84442911e-04   1.61728531e-04]
# cleap : how ['how', 'part', 'of'] [  9.98397171e-01   6.60595542e-04   5.63754176e-04]
# power , sir ['them', '.', 'in'] [ 0.95531017  0.01100455  0.00645457]
# our tongue to ['but', 'banished', 'be'] [ 0.27617186  0.13405277  0.07859736]
# courage ; here ['now', 'even', 'lie'] [ 0.86411464  0.10770127  0.00397503]
# OF GAUNT : [',', ':', 'And'] [ 0.334782    0.17194571  0.10510729]
# the wars as ['Had', 'eats', 'as'] [ 0.50092304  0.23521559  0.05715036]
# Urging of arder ['arder', 'of', 'to'] [ 0.67074007  0.07689372  0.04017139]
# bringing winged one ["'", 'a', 'excellent'] [ 0.8999064   0.0473123   0.01218186]
# sirs , As ['As', 'Even', 'France'] [  9.96379435e-01   3.79906647e-04   2.46411597e-04]
# , I would ['be', 'not', 'do'] [ 0.14061493  0.12225939  0.05139254]
# Fie , wife ['should', ',', 'I'] [ 0.31549472  0.29698902  0.1182177 ]
# their patience . ['KING', 'poor', 'belong?'] [ 0.97134846  0.00847407  0.00328734]
# and we shall ['be', 'a', 'them'] [ 0.14054739  0.05828564  0.04844325]
# be great in ['your', 'this', 'toil'] [ 0.30143368  0.13165222  0.07075684]
# not? MACBETH : [':', 'So', 'you'] [ 0.43326256  0.14060557  0.10725371]
# me , When ['I', 'you', 'thou'] [ 0.15257469  0.09588792  0.0708583 ]
# he is but ['a', 'this', 'his'] [ 0.3047612   0.08316692  0.04678474]
# have thee all ["'", 'hand', 'her'] [ 0.07543473  0.06363934  0.03253932]
# Their stods are ['are', 'They', 'banished'] [  9.93965209e-01   3.29118990e-03   5.43400412e-04]
# gentleman and joiner ["'", 'Your', 'deed'] [ 0.23477517  0.16027738  0.05415625]
# Well , my ['look', 'lord', 'brook'] [ 0.37761855  0.24203011  0.02055465]
# so slire their ['their', ',', 'I'] [ 0.93548918  0.03155867  0.00495543]
# Could her son [';', 'for', 'in'] [ 0.23517026  0.09929693  0.08618876]
# us be taken [',', 'as', 'thou'] [ 0.98556596  0.00185562  0.00176276]
# so call them ['are', "'", '.'] [ 0.43924528  0.33510193  0.02697337]
# - board affected ['affected', 'know', 'money'] [ 0.33121407  0.17240793  0.13015583]
# you have no ['myself', 'give', 'realm'] [ 0.03562688  0.02937203  0.02097243]
# been consent . ['Her', 'was', 'I'] [ 0.370334    0.11178932  0.08217695]
# . I cannot ['have', 'be', ':'] [ 0.09842002  0.07124588  0.04853535]
# was seen a ['new', 'undoublet', 'Is'] [ 0.3058421   0.20221271  0.05329661]
# handkerchief is the ['is', 'young', 'night'] [  9.96950865e-01   4.33849753e-04   2.38754743e-04]
# though not construct ['presently', 'Lives', 'we'] [ 0.14617451  0.05151335  0.05120734]
# , or shall ['his', 'I', 'a'] [ 0.20790833  0.06059165  0.05516596]
# honour . TRANIO [':', 'me', 'thy'] [ 0.98104262  0.00253233  0.00104712]
# coming . ROSALIND [':', 'we', 'and'] [ 0.90752387  0.0707374   0.00337442]
# She sent me ['me', 'noble', 'make'] [  9.99975801e-01   9.44488511e-06   2.77384788e-06]
# ' s faces ['hath', ':', 'I'] [ 0.30517289  0.17590098  0.09178852]
# , beat your ['to', 'purpose', 'extreme'] [ 0.08663937  0.05692096  0.04199895]
# Not purpose cold ['cold', 'one', 'to'] [ 0.75642723  0.0272107   0.0127787 ]
# consul - blesd ['blesd', 'But', 'THESEUS'] [ 0.87462848  0.10469095  0.00181272]
# again , but ['we', '-', 'bringing'] [ 0.16004522  0.0787985   0.07501133]
# well stay ' ["'", 'of', 'air'] [ 0.4058274   0.33978814  0.05120585]
# ; and her ['of', 'then', 'be'] [ 0.08631419  0.05965279  0.02844788]
# . Publius three ['It', 'three', 'Till'] [ 0.90410364  0.06838666  0.00463134]
# it smiles to ['me', 'to', 'the'] [ 0.86528236  0.10695265  0.01626379]
# of it owed ['!', '.', 'as'] [ 0.87155998  0.0191393   0.01089867]
# volume These flittery ['flittery', 'night', 'The'] [ 0.91903031  0.01472555  0.00957594]
# head? Second Murderer [':', 'Murderer', 'Second'] [ 0.59327632  0.40192267  0.0014483 ]
# Of the conceit ['to', "'", '.'] [ 0.37140337  0.09783798  0.07167003]
# , Which craveth ['his', 'a', 'I'] [ 0.31673774  0.2609773   0.04350802]
# a cheek ; ['now', ';', 'or'] [ 0.97130394  0.01475901  0.00440583]
# ANDRONICUS : She ["'", 'will', 'I'] [ 0.78987801  0.18349132  0.01927314]
# s very bastard ["'", ',', 'lusty'] [ 0.33186293  0.07504635  0.04744067]
# s affairs ; ['which', 'I', 'good'] [  9.81757820e-01   1.20176366e-02   4.24662430e-04]
# and goodly care [',', 'me', '-'] [ 0.80544645  0.07809711  0.02102857]
# Show me Command ['.', ';', 'Command'] [ 0.62675881  0.12808818  0.09027896]
# deeds Would do ['to', 'do', 'base'] [ 0.3427794   0.28752548  0.16949581]
# Yet you ' ['d', 'tis', "'"] [ 0.18645197  0.0428716   0.03803016]
# bad and king ['Juno', 'in', "'"] [ 0.857705    0.05950911  0.01469225]
# to thy reason ["'", 'I', 'shall'] [ 0.61170369  0.12689084  0.09710982]
# not see her ['Good', 'age', 'in'] [ 0.03218509  0.03121194  0.02446679]
# HAMLET : What ["'", 'What', 'sweet'] [ 0.5845176   0.11746991  0.06617223]
# : But father ["'", 'that', 'I'] [ 0.12866612  0.11030051  0.08520734]
# wouldst proceed again ['again', 'DAUPHIN', 'which'] [ 0.47738042  0.30973363  0.08672652]
# Well , look ['they', 'you', 'my'] [ 0.15196809  0.06093179  0.06040652]
# say . CYMBELINE ['JOHN', 'But', 'Thersitania'] [ 0.217934    0.06897844  0.06569345]
# our continual gates ['the', 'that', 'gates'] [ 0.7163204   0.15964775  0.04190976]
# Equinius : Affection [':', 'I', 'sweet'] [ 0.98558873  0.0096764   0.00267052]
# daylight but it ['but', 'know', ':'] [ 0.95303917  0.0053163   0.00317336]
# blesd ; But ['But', 'we', 'know'] [ 0.95051903  0.02202797  0.00590999]
# , with a ['I', 'answer', 'way'] [ 0.03727743  0.01553217  0.0093594 ]
# Being banished for ['for', 'till', 'his'] [ 0.98625886  0.00277369  0.00275989]
# person , but ['many', 'but', 'song'] [ 0.40107465  0.09043525  0.08715273]
# not to pray [',', 'and', 'their'] [ 0.27674019  0.05086091  0.04156245]
# put him from ['on', 'Is', 'her'] [ 0.21675315  0.0938087   0.0425966 ]
# , The rax ['are', 'I', 'good'] [ 0.54043204  0.05082981  0.0336739 ]
# whose ancestor hath ['hath', 'to', 'made'] [  9.93255019e-01   2.14491622e-03   2.65267357e-04]
# , That would ['be', "'", 'of'] [ 0.10753199  0.05242582  0.03165737]
# , sir , ['I', 'a', 'she'] [ 0.42243353  0.06474105  0.04833543]
# First Soldier : [':', 'I', 'To'] [ 0.56086898  0.08295776  0.06802107]
# of it was ['the', 'as', 'on'] [ 0.02869701  0.024559    0.02390799]
# , the world [',', '.', 'of'] [ 0.21057636  0.20637713  0.0772296 ]
# : Sir , ['I', 'you', 'his'] [ 0.37015551  0.04982148  0.04372111]
# Let them ask ['me', 'be', 'thy'] [ 0.53209788  0.12205626  0.11338399]
# upon their safety [':', 'hand', 'of'] [ 0.07253277  0.06711739  0.0648811 ]
# s taste : ['adversary', 'one', 'find'] [ 0.11622102  0.04016851  0.03786039]
# by ten , ['do', 'thou', 'I'] [ 0.77245593  0.05947317  0.05771878]
# I was more [':', 'a', ';'] [ 0.18214317  0.08879531  0.04152008]
# add their swords ['came', 'As', 'I'] [ 0.20135276  0.14881708  0.0774643 ]
# Nurse : Pray [',', 'Pray', 'Ay'] [ 0.47087094  0.22835308  0.13431114]
# her to know [';', 'be', ','] [ 0.18679373  0.10241896  0.08675621]
# , the day ['of', ',', '.'] [ 0.69142473  0.05038429  0.04971398]
# from strings in ['in', 'them', 'it'] [  9.99947071e-01   8.47868523e-06   7.62198397e-06]
# , I say ['a', "'", 'their'] [ 0.16183352  0.13679905  0.07331654]
# will fall , ['and', 'thy', 'BRUTUS'] [ 0.66549754  0.01641903  0.01446836]
# , my lord [',', ';', '.'] [ 0.50950557  0.2504718   0.07392749]
# men here of ['it', 'thy', 'nothing'] [ 0.18865438  0.09220956  0.04383377]
# ' d for ['the', 'his', 'I'] [ 0.16208787  0.04291126  0.03775973]
# drink , That ['in', 'his', 'Rome'] [ 0.34434047  0.28181332  0.0963534 ]
# from our fair ['and', '-', ','] [ 0.24051489  0.14059459  0.08648892]
# entreat thee , ['and', '-', 'than'] [ 0.84019023  0.02906222  0.01486417]
# , good Master ['her', 'that', 'the'] [ 0.34925112  0.17763188  0.10040309]
# epithantic , By ['By', 'I', 'thou'] [ 0.69301343  0.16535941  0.09325618]
# have fall ' ['s', 'knows', 'grave'] [ 0.52415216  0.37656969  0.00735258]
# must not see ['the', ',', 'me'] [ 0.14022812  0.10050035  0.05986999]
# little outward To ['To', 'might', 'CORIOLANUS'] [ 0.90292692  0.0227949   0.01609086]
# am . Chiron [':', ';', 'their'] [ 0.42105606  0.1807525   0.10015351]
# child should buy ['buy', 'To', 'trup'] [ 0.44630843  0.10266738  0.07928097]
# Look thee , ['and', 'I', 'in'] [ 0.75376612  0.09103265  0.02492397]
# letters out , ['be', 'eat', 'Murder'] [ 0.28303301  0.27389574  0.14314158]
# not , but ['I', 'a', 'the'] [ 0.25340784  0.10576396  0.05398154]
# is his wits ['and', ';', 'a'] [ 0.55523038  0.11263388  0.0826613 ]
# domething hunting himself ['himself', 'his', 'where'] [  9.90298748e-01   8.42228066e-03   2.12708168e-04]
# loss . So ['I', 'think', 'sweet'] [ 0.7461797   0.07014213  0.02248011]
# I will not ['be', 'this', 'thee'] [ 0.0586498   0.03791799  0.0329352 ]
# the life brightly ['this', 'then', 'thou'] [ 0.12779532  0.07640729  0.07158817]
# , On my ['my', 'went', 'seas'] [ 0.630826    0.11774781  0.01452885]
# captive and to ['to', 'thee', 'and'] [  9.90644813e-01   9.59320460e-04   6.00135943e-04]
# : Give me ['a', 'the', 'thy'] [ 0.44758779  0.240073    0.21287878]
# am sleeping From ['their', 'From', 'hand'] [  7.05510557e-01   2.87579358e-01   6.39041769e-04]
# goodly master , ['heat', 'his', 'chamber'] [ 0.27052364  0.17397708  0.07292157]
# he was that ['a', "'", 'on'] [ 0.18696094  0.05372665  0.04499041]
# sing for so ['I', ',', 'are'] [ 0.93360448  0.03628622  0.01438958]
# ground , whereof ['I', 'are', 'shall'] [ 0.98884958  0.00191065  0.00127877]
# cousin ; And ['know', 'or', 'Sir'] [ 0.24865222  0.21462961  0.10784353]
# ' tis talk ['of', 'doth', 'yourselves'] [ 0.97416955  0.00504893  0.00475048]
# Those that he ['he', 'in', 'that'] [  9.99246955e-01   1.89275219e-04   1.54513313e-04]
# I saw thee ['of', '.', "'"] [ 0.20225558  0.09171747  0.06674644]
# should I , ['be', "'", 'them'] [ 0.10023633  0.04619145  0.03019429]
# , A man ["'", 'shall', 'had'] [ 0.10324342  0.08074708  0.06918989]
# bodies from the ['discharge', 'to', 'this'] [ 0.3900694   0.24037208  0.03845495]
# she might find ["'", 'have', 'be'] [ 0.25342306  0.07249947  0.05774046]
# to day , ['and', 'I', 'but'] [ 0.10411739  0.07825883  0.06151588]
# and not have ['a', 'the', 'well'] [ 0.10403581  0.0298879   0.02677149]
# and I am ["'", 'a', 'to'] [ 0.07765298  0.06108459  0.05097898]
# , To quickly ['her', 'them', 'on'] [ 0.13137607  0.08938365  0.0804209 ]
# you , because ['I', 'have', 'that'] [ 0.21385358  0.07831004  0.03846946]
# , the heavy ['are', 'so', 'of'] [ 0.44251037  0.07703865  0.06553703]
# ' s arms ['the', ':', 'her'] [ 0.10707501  0.07502675  0.07263331]
# to think he ["'", ':', 'be'] [ 0.55935186  0.06511037  0.03515112]
# that thyself will ['an', 'will', 'in'] [ 0.9641614   0.01767886  0.00493138]
# a maid all [':', 'but', 'I'] [ 0.38998252  0.32783118  0.18003473]
# esteemed behaviors ' ["'", 's', 'a'] [  9.98652279e-01   7.09939282e-04   2.22671064e-04]
# and thus did ['not', 'with', 'to'] [ 0.14496525  0.12536289  0.08271332]
# arrest them . ['.', 'them', 'KING'] [ 0.98426348  0.00612303  0.003355  ]
# villain , And ['the', 'exhibition', 'I'] [ 0.19827701  0.19312119  0.13338274]
# not true . ['KING', 'RICHARD', 'what'] [ 0.14211126  0.02534414  0.02494308]
# and brought him [';', 'me', ','] [ 0.38523281  0.11125114  0.10808449]
# gentleman , So ['three', 'get', "'"] [ 0.15651464  0.12943558  0.09910297]
# of men , ['it', 'and', 'a'] [ 0.0771318   0.06390939  0.04410908]
# had up , ['hand', 'your', 'subjects'] [ 0.18639082  0.07539371  0.04881507]
# do gold . ['I', 'But', 'gentle'] [ 0.15478297  0.07566871  0.0654389 ]
# , As a ['I', 'over', 'entrances'] [ 0.07975341  0.03020756  0.02373888]
# you thou art ['a', 'more', 'this'] [ 0.37817091  0.11702782  0.0170126 ]
# goodly chamber . ['hospish', 'And', 'falsely'] [ 0.64679575  0.07278791  0.02184897]
# your glory? QUEEN [':', 'QUEEN', 'grace'] [ 0.6092422   0.30943865  0.00913021]
# One estate more ['more', 'her', 'of'] [ 0.89084828  0.09381819  0.01005624]
# our daughter give ['them', 'me', 'to'] [ 0.10835204  0.09148466  0.0759635 ]
# John , And ['her', 'this', 'when'] [ 0.19254194  0.08880734  0.08349228]
# enemy have fall ['then', 'fall', 'of'] [ 0.21878125  0.14528859  0.09561519]
# thine eyes for ['are', 'not', 'go'] [ 0.41756094  0.34261486  0.04575405]
# To bisk which ['with', 'which', 'people'] [  6.99471235e-01   2.96219945e-01   6.64016989e-04]
# , I would ['be', 'not', 'do'] [ 0.14061493  0.12225939  0.05139254]
# daughter than Hecuba? ['When', 'eat', 'Benedick'] [ 0.10011276  0.09614409  0.07114463]
# That every one ['of', 'one', 'look'] [ 0.14451322  0.07593945  0.03073667]
# . LADY MACBETH [':', 'MACBETH', 'What'] [ 0.9362669   0.03988794  0.00965091]
# dust - confounded ['confounded', '-', 'I'] [ 0.4862774   0.32876074  0.03963746]
# Let us be ['see', 'learn', 'wise'] [ 0.23942001  0.12706544  0.06265976]
# Would dream so ['for', 'was', 'some'] [ 0.3930417   0.09714372  0.08957573]
# his grace to ['I', 'every', 'in'] [ 0.14849444  0.07927751  0.06347806]
# between my eyes [',', 'Thou', 'lord'] [ 0.14116552  0.08321113  0.07738552]
# Provost : A ['are', 'I', 'would'] [ 0.67490929  0.20239709  0.07124456]
# they are a ['of', 'extreme', 'kind'] [ 0.03458753  0.02214052  0.02162171]
# us for a ['as', 'bloody', 'As'] [ 0.11044216  0.09978484  0.04848838]
# ll walk my ['But', 'are', 'my'] [ 0.28878456  0.08789828  0.06843957]
# likey . QUEEN ['QUEEN', ':', 'CASSIUS'] [ 0.44685572  0.19873326  0.11276033]
# towards your add ['add', 'I', 'your'] [ 0.67910373  0.26202062  0.0148666 ]
# The base circumstance ['may', 'a', 'I'] [ 0.46206969  0.21723667  0.06465539]
# , Who made ['not', 'will', 'your'] [ 0.27817434  0.12249894  0.11412463]
# obscured kisses . ['.', ':', 'Gentleman'] [ 0.51218945  0.3506071   0.01690906]
# pride and spaces ['spaces', '.', 'bloody'] [ 0.96554172  0.00384917  0.00231727]
# : of your ['is', 'I', 'bloody'] [ 0.01955266  0.01569615  0.01285049]
# too certain . ['sensual', 'racks', 'AJAX'] [ 0.08258639  0.0712181   0.07118937]
# will propose Their ['to', 'Their', 'a'] [ 0.27209362  0.13040935  0.06471381]
# I should go ['be', ',', '.'] [ 0.23229761  0.21893109  0.08326771]
# be pitiful ; [';', ',', 'I'] [ 0.91212821  0.05619354  0.00896847]
# Till I am ['shall', 'hath', 'am'] [ 0.10347053  0.09668126  0.04931609]
# hath been left ['yet', 'son', 'gave'] [ 0.29045185  0.28653136  0.21055728]
# a baser ' ['s', "'", 'letter'] [ 0.45114043  0.34974882  0.15261002]
# pray your leisure ['and', "'", 'Would'] [ 0.12486216  0.08818441  0.05558762]
# sun as soonman ['soonman', 'stroke', 'now'] [ 0.77114844  0.11799595  0.02906428]
# their heart shall ['That', 'have', 'a'] [ 0.28721982  0.06001923  0.03337009]
# , We are ['her', 'for', 'not'] [ 0.18667533  0.09438788  0.09376841]
# mine enemy , ['But', 'those', 'yet'] [ 0.38156015  0.18936321  0.0216114 ]
# Whose words are ['o', 'are', 'he'] [ 0.37686113  0.12332495  0.0665582 ]
# of love ! ['Good', 'If', 'go'] [ 0.1298629   0.05213382  0.03938301]
# marriage gives me ['me', 'I', ':'] [ 0.76259351  0.18634854  0.0264972 ]
# poor sons , ['for', 'some', 'to'] [ 0.37702456  0.21986991  0.09686745]
# thou more than ['a', 'for', 'this'] [ 0.25134066  0.18892746  0.09531072]
# : What makes ['my', 'thou', 'and'] [ 0.35040203  0.13138045  0.06262732]
# mad and tender ['to', 'come', 'the'] [ 0.13479576  0.11382604  0.06328906]
# ' ll not ['be', 'are', 'your'] [ 0.07547873  0.05799033  0.02703415]
# my poor remembrance ['to', 'this', ','] [ 0.6891697   0.03394175  0.02681621]
# , and then ['I', ',', "'"] [ 0.19319864  0.06472594  0.0553498 ]
# you? no : ['know', 'I', 'TRANIO'] [ 0.37494349  0.06061071  0.02591667]
# O ho ! ['wouldst', '!', 'Men'] [ 0.3224425   0.24660334  0.05173669]
# hope will never ['this', 'you', 'air'] [ 0.0836178   0.0640121   0.05347845]
# pray thee . ['know', 'Would', 'hand'] [ 0.07868185  0.06007181  0.04884195]
# there are as ['for', 'thou', 'this'] [ 0.18301713  0.07508924  0.06587561]
# , I will ['not', 'be', 'am'] [ 0.11461661  0.08928453  0.03964243]
# Of those such ['such', "'", 'angel'] [ 0.1891658   0.06908784  0.05686245]
# I will prove ['to', 'thee', 'more'] [ 0.20857428  0.09293722  0.06303658]
# very bastard couch ['d', "'", ';'] [ 0.85571033  0.07009871  0.01298957]
# in bedick and ['Have', 'and', 'she'] [ 0.54757106  0.32294187  0.0135283 ]
# before I fear [',', '.', 'not'] [ 0.30716497  0.1114777   0.1014931 ]
# own conusteries ; [';', 'In', 'very'] [ 0.33107311  0.29397291  0.12011103]
# never draw , ['every', 'the', 'behind'] [ 0.38746023  0.11709623  0.06284654]
# know , have ["'", 'her', 'if'] [ 0.116358    0.09786691  0.09309506]
# while my wrathful ['wrathful', 'I', 'reads'] [ 0.1909494   0.07248989  0.05933139]
# AJAX : I ['will', 'woes', 'know'] [ 0.36353353  0.12952226  0.08586852]
# , till you ['are', 'must', 'shall'] [ 0.49768654  0.45804584  0.00452975]
# in single shore [',', '.', ';'] [ 0.83268917  0.04987428  0.01462935]
# with a grief [':', 'of', 's'] [ 0.76618433  0.06337856  0.04125939]
# ; for I ['am', 'will', 'had'] [ 0.11970092  0.09366108  0.05746675]
# of all my ['boy', 'lives', 'practise'] [ 0.1370929   0.06665763  0.02562281]
# tell him he [':', 'then', 'her'] [ 0.17286859  0.16396004  0.14422169]
# linger : This ['This', 'What', ':'] [  9.88596976e-01   5.96975395e-03   9.62536375e-04]
# enough . MACBETH [':', 'of', 'No'] [  9.96629894e-01   1.18912128e-03   5.45512361e-04]
# , lichard part ['Nurse', 'would', 'part'] [ 0.79536605  0.08609185  0.06364934]
# I myself will [',', 'your', 'set'] [ 0.06939884  0.06813074  0.04441486]
# , my good ['lord', 'that', 'I'] [ 0.32286501  0.07703857  0.05752357]
# dost thou begin [':', 'then', 'begin'] [ 0.53683305  0.16726494  0.05013361]
# ' ll learn ['not', 'in', 'the'] [ 0.20737189  0.13995828  0.0808811 ]
# more devil to ['possess', 'to', 'the'] [ 0.92107189  0.06754588  0.00360745]
# light their breath ['way', '.', 'very'] [ 0.42740035  0.40089217  0.11567151]
# given upon our ['our', 'streets', 'life'] [ 0.97714257  0.00345438  0.00179611]
# A moderate ship ['ship', 'hand', "'"] [ 0.86305881  0.06535172  0.01973819]
# are disposition ' ['d', "'", 'give'] [ 0.89947468  0.03075952  0.03073395]
# I swear a ['way', "'", 'follow'] [ 0.05853039  0.0283339   0.02104637]
# last , a ['I', 'When', 'right'] [ 0.32583284  0.31414962  0.0391795 ]
# garland . Good ['Good', 'I', 'we'] [ 0.90372318  0.07034649  0.00785168]
# , Unto Antipholus [':', 'honour', 'know'] [ 0.93223876  0.00690789  0.00620161]
# now : But ['we', 'was', 'that'] [ 0.20411849  0.08605806  0.04922656]
# follow thy chamber ['d', 'in', 'his'] [ 0.26418579  0.17802261  0.0945977 ]
# , poor a ['to', 'in', 'his'] [ 0.1183948   0.04759086  0.03591204]
# like a rank ['I', 'upon', 'call'] [ 0.29726627  0.11000437  0.08178803]
# coward . OCTAVIUS ['OCTAVIUS', 'sir', 'CASSIUS'] [  9.89795625e-01   2.34926026e-03   8.37955042e-04]
# than the day ['of', '.', ';'] [ 0.5283916   0.11109392  0.04809611]
# . PANDARUS : ['So', "'", 'I'] [ 0.87593949  0.08428115  0.00419246]
# wash ' d ['d', "'", 'LADY'] [ 0.8201533   0.15173234  0.00753908]
# faithful , I ['Didst', 'had', 'I'] [ 0.70462513  0.06762831  0.03560527]
# be got as ['.', 'as', 'her'] [ 0.56987292  0.10841677  0.09613194]
# you do . ['Second', 'CASSIUS', 'undoublet'] [ 0.05988881  0.03601696  0.03568896]
# dream too , ['me', 'for', 'To'] [ 0.72651827  0.08292024  0.06193187]
# And open with ['good', 'meeding', 'As'] [ 0.11974595  0.06083173  0.05793184]
# by disprezage and ['and', 'rude', 'thou'] [ 0.8210153   0.11497238  0.04560528]
# , He cannot ['be', 'have', 'is'] [ 0.36995673  0.11904024  0.06156885]
# with gallant by ['by', ':', 'Well'] [ 0.93995839  0.02833706  0.00572215]
# s good that ['her', 'I', 'were'] [ 0.2260849   0.11597867  0.02602199]
# I knew the ['bloody', ':', 'we'] [ 0.83261871  0.05980111  0.04847762]
# safe countrymen : ['some', 'others', 'therefore'] [ 0.93425465  0.03795563  0.01346099]
# if she have ['curse', 'ay', 'had'] [ 0.07748397  0.07692602  0.07261553]
# , I will ['not', 'be', 'am'] [ 0.11461661  0.08928453  0.03964243]
# Second Senator : ['Well', 'Nor', 'BOLINGBROKE'] [ 0.82601249  0.05684146  0.03352396]
# . KING lEAR [':', 'V', 'One'] [ 0.25913635  0.10188907  0.0519181 ]
# glorious charge . ['departure', 'friends', 'charge'] [ 0.35274801  0.10458602  0.07107716]
# ho ! Sitmise ["'", 'a', 'Say'] [ 0.98018277  0.00533391  0.00468704]
# coins are well ['well', 'haste', 'sensual'] [  9.97865021e-01   4.37815354e-04   3.36380763e-04]
# strike without state ['that', 'of', 'now'] [ 0.49597561  0.31143954  0.0262131 ]
# the Lines , ['it', 'I', 'what'] [  9.92700517e-01   2.61074607e-03   6.97409618e-04]
# ! TRINCULO : ['I', 'That', "'"] [ 0.57597071  0.21169166  0.13964516]
# knowing this but ['but', 'Your', 'Grew'] [ 0.8551529   0.05204342  0.02860812]
# And , O ['to', ',', 'she'] [ 0.1980855   0.17697589  0.07915387]
# Been known to ['to', 'thee', 'that'] [ 0.97637594  0.00657307  0.00267251]
# : He did ['be', 'is', 'not'] [ 0.32540902  0.07152379  0.07031489]
# fates of death ['of', '.', ':'] [ 0.67369896  0.05613395  0.04185404]
# fortune twice will ['for', 'will', 'in'] [ 0.60426873  0.38939211  0.00097612]
# by your fair [',', 'thou', 'envy'] [ 0.17230202  0.06532358  0.05416581]
# walked with people ['with', 'people', "'"] [ 0.44686455  0.44130513  0.0654671 ]
# do not threw ['lord', 'be', 'to'] [ 0.10401037  0.04633949  0.04625807]
# still so straight [':', 'children', 'I'] [ 0.73154902  0.09901951  0.01901847]
# certain death to ['to', 'death', 'this'] [ 0.24860336  0.17196323  0.05518729]
# rich confers Was ['Was', 'all', 'your'] [ 0.89810508  0.02421944  0.01972046]
# ourselves ; there ['there', 'with', 'see'] [ 0.77960289  0.04372369  0.01937967]
# do ' t ['from', '.', 'not'] [ 0.11881094  0.09957979  0.06306037]
# And dat desires ['desires', 'and', 'she'] [  9.93381500e-01   9.43467894e-04   5.61591703e-04]
# with a friend ['I', ',', "'"] [ 0.18278863  0.16234201  0.07761025]
# . MALVOLIO : ['I', 'Nay', 'As'] [ 0.14715816  0.12650199  0.08879229]
# EMILIA : Where ['here', 'man', 'Where'] [ 0.2786895   0.14019202  0.12959413]
# believe no eye ['eye', 'The', 'EDGAR'] [ 0.94789833  0.01716967  0.00266055]
# not she , ['look', 'be', 'I'] [ 0.07386088  0.06716332  0.06408983]
# discourser of my ['my', 'LAUNCE', 'Pisa'] [ 0.99002939  0.00624127  0.00101913]
# me , How ['I', 'thou', 'these'] [ 0.48346266  0.01908715  0.01616111]
# , but and ['I', "'", 'morrow'] [ 0.29624495  0.039118    0.02783609]
# MARGARET : Nay [',', 'I', "'"] [ 0.45825475  0.29358917  0.04856639]
# would behold Mine ['grace', 'your', 'friend'] [ 0.87192219  0.05895342  0.02102512]
# thou true . ['It', 'Pirator', 'women'] [ 0.06086489  0.04025324  0.03835431]
# for love ! ['we', '-', 'As'] [ 0.12945569  0.07428512  0.05740875]
# by your substance ['.', ',', "'"] [ 0.50644016  0.0797169   0.0324531 ]
# My son , ['if', 'and', 'thou'] [ 0.28549448  0.06850802  0.06765669]
# now , Leave ['a', 'we', 'that'] [ 0.15837935  0.12138236  0.07330734]
# see your bear ["'", 'since', 'I'] [ 0.11056498  0.04399309  0.03680541]
# : Open them ['thy', 'them', 'be'] [ 0.91790688  0.05746276  0.00389698]
# the pregnant fellow ['fellow', '-', 'To'] [ 0.94890535  0.00809487  0.00784973]
# , speak you ['.', 'a', 'will'] [ 0.19699717  0.11120499  0.10531081]
# go hand without ['let', 'by', 'at'] [ 0.11005297  0.05766074  0.03851179]
# scourge Of do ['do', 'to', 'heard'] [ 0.97016466  0.00399559  0.00339915]
# Sitmise till noble ['noble', 'must', ','] [ 0.9931612   0.00210819  0.00156324]
# Humphrey ' s ["'", 's', 'With'] [ 0.55769509  0.4021872   0.003636  ]
# leader here about ['about', ':', 'I'] [  9.85008955e-01   9.66961775e-03   7.60281284e-04]
# ' s some ['shall', 'face', 'ships'] [ 0.02055374  0.01783381  0.01571703]
# how early so ['so', 'was', 'safety'] [ 0.89385307  0.01535826  0.01361277]
# ' servant come [',', 'to', 'such'] [ 0.67846674  0.11159564  0.10057203]
# let me make ['them', 'more', '-'] [ 0.089448    0.06797399  0.04992171]
# GONZALO : What ['What', 'here', ':'] [  9.99943018e-01   1.66143946e-05   5.30699344e-06]
# dependance : of ['of', ':', 'then'] [ 0.66770101  0.12548159  0.0589603 ]
# no learning praised ['praised', 'spent', 'less'] [ 0.59770077  0.24336331  0.02969517]
# PETRUCHIO : I ['I', ':', 'have'] [  9.98800635e-01   6.05574111e-04   7.44636927e-05]
# Sunday ladies : ['face', 'Come', 'ladies'] [ 0.36056313  0.14522222  0.14368168]
# a service . ['never', 'I', 'this'] [ 0.22960722  0.06103085  0.03621248]
# upon our airs ['But', 'her', 'fair'] [ 0.17642368  0.05551375  0.0540106 ]
# turns the sisters ['sisters', 'dear', 'all'] [ 0.95228857  0.00722397  0.00373727]
# patient . MENENIUS ['MENENIUS', '.', ':'] [ 0.84607458  0.05545727  0.03600289]
# choice ; Which ['Which', 'keeping', 'Your'] [  9.98983443e-01   3.02909320e-04   2.88549258e-04]
# be more : ['a', 'for', 'but'] [ 0.22826231  0.21441397  0.14276882]
# of mighty soldiers ['men', 'Will', 'hands'] [ 0.7683838   0.0176211   0.01487508]
# shadow? Separator : [':', 'know', 'very'] [ 0.55304939  0.14089724  0.04476316]
# things in earthly [':', 'service', 'a'] [ 0.1986455   0.17115985  0.11529154]
# of praise more ['to', 'as', 'hope'] [ 0.3351503   0.13503961  0.08710851]
# costly doth the ['the', 'die', 'field'] [ 0.17930792  0.09960431  0.0721255 ]
# to feed , ['it', 'a', 'words'] [ 0.35510257  0.11498401  0.03956208]
# nuptial prince ! ['prince', 'pray', 'Ferminence'] [ 0.83069605  0.02904589  0.00895413]
# use the likewise ['my', 'lord', 'that'] [ 0.70758855  0.06070323  0.04730409]
# toldst how now ['now', 'how', 'of'] [  9.98744369e-01   8.29829602e-04   6.14970049e-05]
# Go with me ['a', 'her', ';'] [ 0.21397844  0.15212856  0.05908216]
# conduct but a ['a', 'but', 'stand'] [ 0.96944582  0.01254408  0.00169029]
# ll none be [':', 'be', 'were'] [ 0.26077685  0.13554457  0.0709221 ]
# dear lord , ['hath', 'been', 'I'] [ 0.54400104  0.07972772  0.05732225]
# wear you are ['jester', ':', 'the'] [ 0.1980335   0.18403506  0.05868151]
# ' s make ['a', 'the', 'that'] [ 0.23870167  0.23203196  0.0677841 ]
# all the morning ['I', '.', 'that'] [ 0.41666302  0.17152652  0.05773974]
# bound from our ['Yes', 'it', 'our'] [ 0.08049063  0.06767114  0.05375815]
# but a queen ["'", 'of', 'shall'] [ 0.30530363  0.09600376  0.04693935]
# will break . ['needs', 'Till', 'on'] [ 0.03927209  0.03252108  0.02721757]
# kept with you ['in', 'army', 'PANDARUS'] [ 0.68256819  0.10871761  0.02104438]
# be for the ['hand', 'Antonius', 'I'] [ 0.13292179  0.05244917  0.02867442]
# : I saw ["'", 'done', 'this'] [ 0.09694438  0.07608279  0.07319532]
# , And in ['the', 'she', 'a'] [ 0.15624152  0.11795139  0.08184648]
# still fair children ['children', 'was', ':'] [ 0.90878725  0.02561577  0.00878915]
# have with the ['hand', 'disposition', 'bloody'] [ 0.11920246  0.05355847  0.04472271]
# you do about [':', '.', ','] [ 0.81780463  0.13577443  0.00836842]
# it by a ['I', 'good', 'envy'] [ 0.02637023  0.01716024  0.0153372 ]
# the audit , ['I', 'hath', 'That'] [  9.99758661e-01   4.91924984e-05   2.11244460e-05]
# with such an ['excellent', 'additions', 'a'] [ 0.07661562  0.06280443  0.06162417]
# known them in ['base', 'the', 'thus'] [ 0.33548859  0.13314025  0.12281292]
# Bawd : That ['O', 'That', ','] [ 0.30970308  0.27580628  0.12840736]
# heaven myself to ['my', 'Margaret', 'set'] [ 0.13476112  0.07129594  0.05774074]
# Write off , ['and', 'that', 'off'] [ 0.62196511  0.31150064  0.01352478]
# Most general strumpets ['care', 'What', 'daughter'] [ 0.50572145  0.32650274  0.05137978]
# aspected , no ['no', 'thy', 'son'] [  9.97179866e-01   1.64563616e-03   5.82113134e-05]
# . AENEAS : ['thou', 'I', 'Come'] [ 0.97909087  0.00337837  0.00141858]
# JOHN : To ['know', 'eye', 'yesterday'] [ 0.10022428  0.05954413  0.03845899]
# hear my daughter ['I', 'Pisa', "'"] [ 0.22386654  0.07819144  0.07306797]
# raffed one another ['another', 'one', 'earth'] [ 0.97089326  0.01566947  0.0040253 ]
# hast not to ['as', 'hear', 'England'] [ 0.22290652  0.16761243  0.12255211]
# physic pantion us ['us', 'the', 'that'] [  9.95956361e-01   2.38762470e-03   4.70688188e-04]
# : But heavy ['are', 'that', 'so'] [ 0.74154693  0.07817204  0.02316449]
# spirit of horns ['tongue', 'thy', 'my'] [ 0.2757073   0.21147883  0.08459245]
# bocks . BRUTUS ['BRUTUS', '.', 'affright'] [ 0.95607919  0.0272326   0.00203378]
# lord , you ['are', 'shall', 'will'] [ 0.37168017  0.04912796  0.048441  ]
# no pity yet ['all', 'yet', 'The'] [ 0.61907929  0.17338456  0.02152876]
# with it That ['I', 'as', "'"] [ 0.11931675  0.06371816  0.03611169]
# prince they are ['I', 'do', 'what'] [ 0.38264504  0.10226142  0.06840476]
# were a pride ['of', '.', 'an'] [ 0.73754412  0.12571229  0.00937276]
# table , cousin [',', 'cousin', 'till'] [ 0.88445163  0.08558124  0.01303598]
# , this is ['to', 'a', "'"] [ 0.08760563  0.07764664  0.05481018]
# this holy boy ['stroke', 'have', 'to'] [ 0.6366455   0.27550232  0.02041877]
# flittery villains and ['and', 'of', 'she'] [  9.76973832e-01   2.17728764e-02   2.69849901e-04]
# pregnant fellow Troilus ['fellow', 'to', ':'] [ 0.68078655  0.1190438   0.0631412 ]
# Thou bear ' ['st', 'run', 's'] [ 0.64795995  0.03171865  0.02651161]
# cap before you ['before', 'in', 'a'] [ 0.83591527  0.14747746  0.00469763]
# . CORIOLANUS : ['Let', 'Well', 'For'] [ 0.21654953  0.15093191  0.08282518]
# me the deep ['!', 'If', 'fled'] [ 0.07594523  0.04723103  0.04676124]
# Gentleman : For ['thou', 'power', 'on'] [ 0.48184648  0.08808085  0.05937864]
# you call on ['my', '.', "'"] [ 0.12016186  0.10590845  0.09279811]
# late thee , ['you', 'us', 'that'] [ 0.37502903  0.23203063  0.06184702]
# go with me ['.', ',', 'by'] [ 0.626504    0.08116407  0.04827663]
# . First Gentleman [':', 'A', 'Like'] [  9.93749738e-01   8.04562354e-04   6.84275583e-04]
# words pent is ['in', 'his', 'is'] [ 0.36173284  0.35963595  0.21723238]
# , bid him ['it', 'hear', 'sight'] [ 0.48445082  0.06579196  0.06437298]
# soul of Cretes ['is', 'Cretes', 'I'] [ 0.26956627  0.05098079  0.04844395]
# from them . ['arms', 'From', 'labour'] [ 0.06095947  0.05935976  0.04076675]
# I will Ferring ['.', ':', 'to'] [ 0.90345329  0.01276218  0.0062683 ]
# , when I ['would', 'was', 'have'] [ 0.28899243  0.15943126  0.10954124]
# got? KING PHILIP ['PHILIP', ':', 'loss'] [ 0.95945948  0.02369889  0.00494054]
# alone ; And ['my', 'thy', 'set'] [ 0.58668894  0.11997382  0.0399355 ]
# liberty , Take ['remember', 'Take', 'man'] [ 0.32445517  0.20571962  0.12362704]
# ' st thou ['upon', 'call', 'me'] [ 0.09350704  0.05614509  0.03497315]
# hast he not ['a', 'hear', 'not'] [ 0.54489738  0.13039142  0.09454071]
# o ' er ['the', 'know', 'breast'] [ 0.74263901  0.05507213  0.02460358]
# marriage , sir ['I', ':', 'sir'] [ 0.86392951  0.07879475  0.01677821]
# hand hath much ['a', 'with', 'charge'] [ 0.11943402  0.06621964  0.06558042]
# add More than ['than', 'virtuous', 'bloody'] [ 0.75919884  0.11289769  0.07448452]
# good sir , ['I', 'the', 'most'] [ 0.39665425  0.04276665  0.03003866]
# come . Here ["'", 'gentleman', 'sweet'] [ 0.21769366  0.12997718  0.08323257]
# Helicanus Will see ['see', 'made', 'Will'] [ 0.92032856  0.05549153  0.00348885]
# LEAR : That ['I', 'are', 'a'] [ 0.35604084  0.05091844  0.03864683]
# reasonable Nature in ['in', 'commission', 'Provost'] [  9.95885551e-01   4.73935099e-04   4.73916123e-04]
# Northumberland that loves ['loves', 'streets', 'gods'] [ 0.98997724  0.00277363  0.00134026]
# Troilus , He ['He', 'follow', 'down'] [  9.92036581e-01   3.31969745e-03   5.23135299e-04]
# night , my ['lord', 'needs', 'OPHELIA'] [ 0.1034382   0.06873468  0.04899153]
# am poor dear ['to', 'or', 'a'] [ 0.43251407  0.14827245  0.13749732]
# and husband he ['.', 'more', 'were'] [ 0.41859195  0.08081478  0.06690238]
# ; here , ['I', 'for', 'be'] [ 0.24823822  0.08394487  0.07996322]
# , ceases riding ['give', 'riding', '.'] [ 0.2023651   0.14379452  0.132783  ]
# ' s affairs [':', ';', 'I'] [ 0.46856952  0.04948358  0.03765976]
# : No , ['I', 'good', 'if'] [ 0.71668792  0.05587517  0.02629115]
# do? SPEED : ['Come', 'know', 'SPEED'] [ 0.78845483  0.06766807  0.05700827]
# be possess ' ['d', "'", 's'] [ 0.88970327  0.1022725   0.00238665]
# him well best ['If', 'lose', 'it'] [ 0.15096383  0.11305439  0.06470617]
# whom we plot ['plot', 'be', 'smiles'] [ 0.71191216  0.05789828  0.02129321]
# ' ll come ['not', '.', 'and'] [ 0.17785089  0.08778999  0.06153391]
# soul , But ['I', 'is', 'First'] [ 0.23151411  0.07896561  0.06507967]
# four and terrible ['terrible', 'and', 'thou'] [ 0.86651325  0.03070747  0.0098659 ]
# Who you will ['cannot', 'your', 'How'] [ 0.18616544  0.15568134  0.04668476]
# pride . Here ['spaces', 'be', 'took'] [ 0.96887189  0.00408903  0.00384882]
# . TALBOT : ['Alas', 'KING', 'No'] [ 0.30220053  0.17992307  0.16437332]
# Cretes under And ['And', 'A', 'Let'] [  9.99055922e-01   4.93183499e-04   1.33053632e-04]
# partly . AUTOLYCUS ['.', ':', 'KING'] [ 0.74493033  0.17346902  0.01026007]
# my curse and ['and', ',', 'I'] [  9.94680345e-01   2.22991896e-03   2.78013089e-04]
# enough , what ['of', "'", 'we'] [ 0.24470204  0.09453621  0.09428797]
# they land Which ['a', 'possess', 'to'] [ 0.17664422  0.13620761  0.10732124]
# and left highest [',', 'thee', '.'] [ 0.38298479  0.30520526  0.09354313]
# is on his ['men', 'good', 'without'] [ 0.09438232  0.04578199  0.03272203]
# see were so ['then', 'this', 'the'] [ 0.13660993  0.04152026  0.03747557]
# Turn Antony : ['it', 'Antony', 'And'] [ 0.49780124  0.26753777  0.05949999]
# , O , ['I', 'a', 'my'] [ 0.19386609  0.05544906  0.03989819]
# wherefore we might ['be', 'judgment', 'I'] [ 0.2126215   0.10667784  0.09768   ]
# ' s bed? ['it', ',', 'and'] [ 0.83834738  0.03117273  0.01721619]
# doubt for all ['all', 'means', 'father'] [ 0.32587376  0.25649232  0.09939726]
# s that the ['must', 'Murder', 'I'] [ 0.05768407  0.05424139  0.03949134]
# PISTOL : Go ['from', 'me', ':'] [ 0.40862677  0.12959377  0.05073813]
# possess ' d ['or', ',', "'"] [ 0.61474931  0.21301709  0.08796179]
# of learned tilt ['and', 'tilt', 'thou'] [ 0.98531961  0.00452223  0.00416311]
# discretion , and ['o', 'thy', 'none'] [ 0.65757513  0.0741859   0.04208294]
# : Sweet widow ['sit', 'of', 'thee'] [ 0.2206603   0.13354081  0.12718067]
# enough . DECIUS [':', 'Which', 'No'] [  9.97878194e-01   4.98895708e-04   4.09560569e-04]
# the old looks ['I', 'number', 'a'] [ 0.68494421  0.04197524  0.03251189]
# thee , The ['run', 'I', 'she'] [ 0.16060258  0.13948159  0.01651384]
# by my master [',', 'in', '.'] [ 0.07801776  0.0740429   0.05257927]
# taking circumstance . ['.', '-', 'would'] [ 0.92702484  0.0104806   0.00588148]
# know? ANTIPHOLUS OF ['OF', ':', 'CAESAR'] [  9.83626962e-01   1.52757522e-02   2.98332889e-04]
# : I prithee [',', ':', 'not'] [ 0.461487    0.40881383  0.04250961]
# I fear , ['and', 'make', 'enough'] [ 0.16886829  0.12155723  0.06309897]
# have lived a ['a', 'Bring', 'Pirator'] [ 0.27219024  0.08380856  0.0367713 ]
# again . First ['HENRY', 'CASSIUS', ':'] [ 0.23231761  0.12992908  0.05768582]
# now were enough [':', '.', ','] [ 0.83079648  0.03953248  0.02060998]
# , Aumerle , ['I', 'are', 'hath'] [  9.99962926e-01   4.64407367e-06   4.08401092e-06]
# . CAESAR : ['I', 'part', 'If'] [ 0.872172    0.0234661   0.02065535]
# , handkerchief is ['is', 'the', 'in'] [  9.99344289e-01   3.46887624e-04   5.20416070e-05]
# fellow , to ['my', 'it', 'that'] [ 0.26099613  0.11134654  0.09227648]
# should therefore enamounce ['heads', ':', 'When'] [ 0.30751634  0.18059444  0.08381555]
# hear : she ['I', "'", 'was'] [ 0.60312778  0.19342421  0.01986716]
# what shall have ['I', 'his', 'a'] [ 0.08843962  0.08206878  0.03593374]
# to all this ['.', 'I', 'of'] [ 0.0808352   0.07820271  0.02664357]
# huntred feebleness , [',', 'and', 'his'] [ 0.37857956  0.10186727  0.07488998]
# is not , ['a', 'this', 'be'] [ 0.15265273  0.08467877  0.04367995]
# is ; count ['of', 'then', 'CLEOPATRA'] [  9.94190753e-01   6.66419743e-04   6.42462051e-04]
# him not strike ['How', 'If', 'a'] [ 0.07946499  0.07466437  0.04518707]
# have always find ['There', 'find', "'"] [ 0.50322807  0.175436    0.08745885]
# , ' tis ['on', 'a', 'not'] [ 0.1273853   0.07947218  0.03828718]
# not Helen ' ['stand', 'name', 'call'] [ 0.32547626  0.19782253  0.15685509]
# answer : he ['have', 'my', "'"] [ 0.64935738  0.06006573  0.03881054]
# hatch ! Fit ['Fit', 'such', 'comfort'] [ 0.95945698  0.0037742   0.00310678]
# write to - ['in', 'lordship', 'and'] [ 0.3710756   0.13414012  0.07373609]
# , Let them ['be', 'me', 'every'] [ 0.55426913  0.05762242  0.0349453 ]
# legs do step ['such', 'step', '-'] [ 0.95186651  0.01404648  0.01109693]
# alack to speak ['speak', 'at', 'it'] [  9.99168873e-01   2.58895394e-04   2.23018156e-04]
# Look , I ['am', "'", 'them'] [ 0.52712715  0.07647761  0.072661  ]
# should ever bear ["'", 'To', 'hast'] [ 0.21085411  0.12653293  0.10581703]
# This we do ['a', 'be', 'not'] [ 0.29314071  0.07214026  0.07133782]
# , thy daughter ["'", 'we', 'most'] [ 0.15049055  0.05177296  0.04118911]
# Norfolk , Hath ['Hath', 'Make', 'to'] [ 0.57506907  0.04031574  0.03358338]
# Would do thy ['now', 'see', 'labour'] [ 0.10554733  0.06589251  0.04623772]
# : I will ['not', 'be', ':'] [ 0.16885063  0.104546    0.08324517]
# thou then have ['your', 'thy', 'a'] [ 0.16670564  0.11373932  0.11159015]
# when a mercy ['upon', 'must', 'I'] [ 0.23527606  0.07360803  0.06935314]
# you lose earthly [',', 'it', 'what'] [ 0.25523233  0.24801794  0.09919416]
# had offer of ['subjects', "'", 'their'] [ 0.10262138  0.08266283  0.07473615]
# a villain than ['I', 'To', 'That'] [ 0.31696239  0.09096137  0.08045322]
# ALBANY : For ['sir', 'For', 'Come'] [ 0.54771292  0.41589949  0.01586174]
# for a guard ['as', "'", 'I'] [ 0.23321785  0.06524306  0.03054128]
# peace gave you ['to', 'you', 'a'] [ 0.48220223  0.22184528  0.15649424]
# No , the ['I', 'men', 'of'] [ 0.04754708  0.04497878  0.04048277]
# , How now [',', '!', 'to'] [ 0.26678818  0.13267916  0.05920713]
# France hath my ['my', 'with', 'if'] [ 0.46007326  0.14234799  0.07239027]
# hear it , ['I', 'shore', 'not?'] [ 0.76265073  0.00929806  0.00800431]
# breaking of her ['her', 'of', 'son'] [  9.95939374e-01   2.14182353e-03   3.14790290e-04]
# : For all ['would', 'the', 'thou'] [ 0.13803118  0.13635854  0.09271514]
# are possess ' ['d', "'", 'or'] [ 0.97161812  0.02438542  0.00160929]
# , and even ['to', 'the', 'with'] [ 0.16132632  0.08749963  0.07635061]
# through myself does [',', 'by', 'my'] [ 0.31542087  0.19022065  0.18770714]
# . TALBOT : ['Alas', 'KING', 'No'] [ 0.30220053  0.17992307  0.16437332]
# I said , ['I', 'But', 'the'] [ 0.3955442   0.17508566  0.03062464]
# and in enfraction ["'", ',', 's'] [ 0.86234617  0.01080273  0.00695354]
# ' s crown ['-', 'the', 'and'] [ 0.28377923  0.11184131  0.05421122]
# he hath not ['a', 'my', 'me'] [ 0.31361964  0.07086026  0.06434619]
# . But what ['I', 'is', 'eyes'] [ 0.17675598  0.09156621  0.05573775]
# poor innocent Roman ['Roman', ':', 'turns'] [ 0.23972172  0.15010303  0.11427439]
# And turn my ['hearts', 'for', 'hell'] [ 0.44614261  0.08803487  0.08493257]
# frozen pride . ['spaces', 'copily', 'EARL'] [ 0.5153653   0.07912131  0.07009967]
# Brutus , disordered ['to', '.', 'a'] [ 0.31591406  0.27648407  0.09733989]
# And do ye [',', ':', 'to'] [ 0.4189924   0.07819307  0.03213113]
# HORATIO : Sir [',', 'That', 'wears'] [ 0.86488169  0.0415573   0.04104068]
# must hew him ['him', 'the', 'now'] [  8.98592770e-01   1.00049809e-01   4.16181982e-04]
# of me language ['.', ',', 'in'] [ 0.86804068  0.06993716  0.01557482]
# . ' Bandible ['of', 'not', 's'] [ 0.48461685  0.27164119  0.03811701]
# I ever lay ['to', 'with', 'the'] [ 0.12722124  0.07309297  0.05040239]
# CLAUDIO : Madam ['I', 'Madam', 'know'] [ 0.62342906  0.15847027  0.06936383]
# No , I ['was', "'", 'will'] [ 0.12044222  0.10306352  0.0534386 ]
# glad you call ['would', "'", 'call'] [ 0.20532906  0.11068794  0.07778835]
# on the point ['of', ':', '.'] [ 0.39612278  0.1138436   0.10989782]
# that I forsake ['a', 'discretion', 'holy'] [ 0.0452112   0.02071971  0.01617651]
# camp : And [':', 'I', 'sweet'] [ 0.96506864  0.02083513  0.00707355]
# from the battle [',', '.', 'place'] [ 0.82621372  0.05134068  0.01628755]
# sin . MISTRESS ['MISTRESS', ':', 'toil'] [  9.98653889e-01   8.69991491e-04   7.03912301e-05]
# if you came ['a', 'make', 'it'] [ 0.19638184  0.07572988  0.05532808]
# Indeed , she ['she', 'in', 'his'] [  9.97801006e-01   4.22169047e-04   4.11308196e-04]
# any thing from ['crimes', 'To', 'thou'] [ 0.46593237  0.07848188  0.02758488]
# was a maid [':', ',', "'"] [ 0.91452974  0.02624812  0.00755371]
# it , He ["'", 'is', 'shall'] [ 0.30115408  0.10131434  0.08705764]
# ...
# score my awe ['awe', 'different', 'It'] [ 0.97039056  0.00526857  0.00514455]
# not to Tarsus [':', 'Come', 'see'] [ 0.18214633  0.10390729  0.03474948]
# be made further ['and', '-', ','] [ 0.33767539  0.15849924  0.05138287]
# confined with an ['I', 'then', 'We'] [  9.92931843e-01   2.50195595e-03   7.29866792e-04]
# steed : Stay [',', ':', 'not'] [ 0.48254642  0.22406852  0.20791721]
# our ripe . ['ANTONY', 'enneared', 'Guilty'] [ 0.74440384  0.05075195  0.02120761]
# recreantly , In ['In', 'I', 'know'] [ 0.88714182  0.03935322  0.00853699]
# s faces , ['hath', 'I', 'Yes'] [  9.46217954e-01   4.85431254e-02   4.78563452e-04]
# defendant ; she ['she', 'his', 'in'] [ 0.97779924  0.01276978  0.0032953 ]
# speaks not my ['my', 'redress', 'not'] [ 0.97820288  0.00279984  0.00165952]
# thoughts of danger ['needs', 'my', 'thence'] [ 0.35576838  0.05791987  0.04646128]
# of barren patience [';', 'and', '.'] [ 0.40156665  0.28240299  0.21501161]
# my liege , ['wise', 'I', 'have'] [ 0.95720822  0.02245088  0.00644927]
# not Titus . ['I', 'MARGARET', 'yet'] [ 0.13929185  0.09754576  0.0446144 ]
# Give me thy ['past', 'deep', 'office'] [ 0.35795528  0.25885215  0.06208903]
# be not for ['a', 'this', 'I'] [ 0.31056854  0.16549209  0.14220335]
# to my beard [',', '.', ';'] [ 0.77285665  0.09277955  0.02766043]
# , fair desire [',', '-', 'not'] [ 0.57413888  0.07516168  0.03720413]
# poison ' d ['I', "'", 'd'] [ 0.69894916  0.08643278  0.02782123]
# grace is any ['condemn', 'taper', 'gone'] [ 0.07561816  0.06737768  0.06205397]
# thou gone very ['TROILUS', ':', 'a'] [ 0.18301135  0.08002932  0.07103965]
# together . AJAX [':', 'MALVOLIO', 'filth'] [ 0.84595567  0.03327119  0.03022186]
# thee a mischief ['.', 'up', 'are'] [ 0.75726211  0.02284989  0.02163767]
# nothing , my ['houses', 'Suffolk', 'well'] [ 0.07140982  0.05676546  0.05044295]
# and treason ' ['place', 's', 'shows'] [ 0.91492361  0.06225789  0.00403426]
# give me brow ['thou', 'a', 'mischief'] [ 0.11274946  0.10805373  0.10713097]
# ' s place [':', ';', 'of'] [ 0.75329185  0.02749733  0.02238194]
# I do not ['be', '.', 'it'] [ 0.06807771  0.03475925  0.02506432]
# . Villain , ['I', ',', 'but'] [ 0.73258716  0.11422155  0.02129684]
# toil ' d ['Contempt', ',', 'in'] [ 0.65181428  0.09865665  0.04856271]
# of a bosom [',', 'of', ':'] [ 0.16809985  0.16788468  0.16466852]
# the prey by ['thy', 'my', 'shoulder'] [ 0.39438167  0.15533885  0.08820775]
# So doth a ['can', 'Whose', 'king?'] [ 0.18919463  0.0582441   0.03388531]
# wisdom to my ['my', 'to', 'lord'] [ 0.8958329   0.07695878  0.01075478]
# Antony : The ['!', 'The', 'is'] [ 0.28760117  0.12829952  0.10472041]
# make her die ['to', ',', 'age'] [ 0.15355203  0.07622305  0.0426886 ]
# not speak ' ['s', 'll', 'KING'] [ 0.2146242   0.06576221  0.05686123]
# You have so ['all', 'are', 'beat'] [ 0.11849784  0.0915511   0.04332547]
# the carriage of ['shall', 'of', 'world'] [ 0.88090998  0.09175397  0.00407965]
# , Perhaps and ['and', 'perform', 'I'] [ 0.87905377  0.07767072  0.03103037]
# my bounties , ['As', 'men', 'But'] [ 0.97283596  0.0036095   0.00210026]
# a stand . ['Before', 'a', 'stand'] [ 0.19317541  0.06939868  0.04332891]
# heart ! THERSITES ['these', 'I', 'you'] [ 0.11768794  0.11184838  0.05148333]
# villain . Madam [':', 'I', 'No'] [ 0.39193377  0.28553435  0.03389888]
# entertainment to this [':', 'gracious', 'fellow'] [ 0.81571543  0.03490605  0.03014372]
# the soldiers , ['men', 'though', 'is'] [ 0.13762674  0.09587456  0.0810895 ]
# SPEED : Well [',', 'I', ':'] [ 0.31821638  0.25847924  0.10053703]
# ; are he ['of', 'for', ':'] [ 0.52350134  0.0793418   0.06361394]
# ' n your ['CAESAR', 'of', 'upon'] [ 0.34326953  0.08169162  0.03707   ]
# what I should ['be', 'hear', 'any'] [ 0.16043574  0.07261128  0.06526273]
# not to set [',', 'you', 'it'] [ 0.41151533  0.07692754  0.03132262]
# a trial? Lady ['I', 'Lady', 'should'] [ 0.85168272  0.12223917  0.00357199]
# us be by ['as', 'I', 'more'] [ 0.1345946   0.09529393  0.07509401]
# t both , ['bloody', 'her', 'cap'] [ 0.16316545  0.15986677  0.14656146]
# for gage ; [',', 'and', 'I'] [  9.98533368e-01   3.43093474e-04   2.75919039e-04]
# we think the ['fortune', 'might', 'man'] [ 0.08646004  0.05581848  0.04968045]
# my nephew presently ['presently', 'To', 'in'] [ 0.32116967  0.24730696  0.23795143]
# sensual being deep ['deep', 'ear', 'with'] [ 0.99186462  0.0029191   0.001336  ]
# thou ranking , ['will', ',', 'but'] [ 0.37262926  0.16176917  0.12782785]
# , And then ['she', 'to', ','] [ 0.12453748  0.07611408  0.0550237 ]
# , That blinds ['of', "'", 'I'] [ 0.19064625  0.07867706  0.05268089]
# I pray you [',', 'and', "'"] [ 0.36293682  0.0445981   0.04023337]
# have been mad ['a', 'enemies', 'Her'] [ 0.25586617  0.06818125  0.06018128]
# all to blood ['I', 'But', 'thou'] [ 0.61675853  0.02358208  0.01242886]
# was discretion , ['o', "'", 'e'] [ 0.40444449  0.3546311   0.04771385]
# my father But ["'", 'country', 'her'] [ 0.22553089  0.09217975  0.08744752]
# Gold , a [',', 'I', 'The'] [ 0.25960886  0.12431088  0.04414438]
# desire , And ['to', 'phulish', 'being'] [ 0.15754944  0.15188809  0.05811062]
# mocks to void ['to', 'void', 'If'] [ 0.66936439  0.15111291  0.02074092]
# it owed by ['That', 'came', '!'] [ 0.65836316  0.1077658   0.05347181]
# now , or ['had', "'", 'was'] [ 0.12563597  0.06939981  0.06699457]
# , he was ['a', 'not', 'that'] [ 0.29737166  0.0296461   0.02342285]
# my liege , ['wise', 'I', 'have'] [ 0.95720822  0.02245088  0.00644927]
# . Here name ["'", ':', 'not'] [ 0.21668673  0.17023157  0.15719256]
# will watch you ['more', 'me', 'no'] [ 0.51029986  0.11893993  0.0813288 ]
# he say this ['art', 'a', 'of'] [ 0.1591173   0.08020034  0.07993156]
# looks of a ['Which', 'The', 'direct'] [ 0.18486568  0.1010042   0.07700229]
# my lord ; ['I', 'thus', 'but'] [ 0.64463234  0.02461695  0.01397733]
# we write to ['in', 'some', 'it'] [ 0.5086903   0.04914174  0.04066405]
# their oaths ; ['It', 'and', 'himself'] [ 0.29834157  0.1436872   0.09151868]
# Tis the loyal ['throws', 'Ade', 'beat'] [ 0.45189309  0.0604319   0.0454084 ]
# mine , though ['may', 'I', 'my'] [ 0.14736053  0.13308941  0.11974637]
# , all under ['thou', 'I', '!'] [ 0.16616204  0.15859686  0.02875667]
# ' d his ['As', 'and', 'in'] [ 0.02068697  0.01413241  0.01366441]
# me now lie [',', '.', 'and'] [ 0.37651864  0.10402782  0.04944286]
# have heard the ['bloody', 'Norfolk', 'his'] [ 0.36475694  0.06307698  0.04219104]
# officers again . ['justice', 'alone', 'If'] [ 0.13405663  0.08678754  0.04305409]
# scaped them . ['them', '.', 'hope'] [  9.94502187e-01   4.04842291e-03   1.99579415e-04]
# to rue to ['Second', 'to', 'them'] [ 0.76038462  0.11301193  0.01757913]
# seems children that ['children', 'be', 'that'] [ 0.30744264  0.29445469  0.13718329]
# thus , A ['not', 'out', 'on'] [ 0.5800249   0.03276278  0.01727277]
# speakings more than ['than', 'for', 'virtuous'] [  9.93894517e-01   2.25641578e-03   2.93719117e-04]
# cold ages of ['the', 'those', 'know'] [ 0.32968888  0.31144172  0.07981173]
# thou begin . [':', 'brets', 'But'] [ 0.56348157  0.11265011  0.0733266 ]
# your wit and ['a', 'to', 'I'] [ 0.05866307  0.04368605  0.02248851]
# hence when thy ['are', 'thy', 'I'] [ 0.35066882  0.0806812   0.06993345]
# moulded Some boy ['boy', 'speak', 'er'] [ 0.96242809  0.00342362  0.0027073 ]
# things . OPHELIA [':', 'I', "'"] [ 0.98218012  0.0047316   0.00192398]
# ' ll asleep ['not', 'are', 'shall'] [ 0.09470129  0.04163133  0.03698976]
# come? BETHEMLO : [':', 'There', "'"] [ 0.19010334  0.13651584  0.13234155]
# - Go parted ['with', 'to', ','] [ 0.94491303  0.01762038  0.01107887]
# Sir , in ['thy', 'I', 'his'] [ 0.20883323  0.13134095  0.06889489]
# and be the ['of', 'I', 'hand'] [ 0.0341619   0.02185045  0.01488504]
# A goodness , ['the', 'BOLINGBROKE', 'been'] [ 0.36658931  0.1514571   0.07148727]
# in my sportify [',', 'That', 'good'] [ 0.07499415  0.05594419  0.04455899]
# follow your grace ['in', 'his', 'a'] [ 0.6325568   0.10702876  0.09001534]
# to day , ['and', 'I', 'but'] [ 0.10411739  0.07825883  0.06151588]
# In at thy ['does', 'further', 'thy'] [ 0.16004452  0.14098996  0.07712995]
# to you . ['CASSIUS', 'Good', 'deputy'] [ 0.14432687  0.01842048  0.01098217]
# wlething of the ['of', 'Butly', 'the'] [  9.92832541e-01   1.51329022e-03   6.65071304e-04]
# FLUELLEN : I ["'", 'I', 'down'] [  8.89000773e-01   1.09702580e-01   5.53019170e-04]
# not . TROILUS [':', 'Lord', 'I'] [  9.96569157e-01   5.10434387e-04   4.32455330e-04]
# d his spirit [',', '.', 'of'] [ 0.28442183  0.25987923  0.18472292]
# not these things ['for', 'a', 'be'] [ 0.25886917  0.17953792  0.02761086]
# ' clock , ['thou', 'Yet', 'I'] [ 0.42555633  0.23744941  0.08651838]
# d ! ' ['s', 'kind', 'labour'] [ 0.16303089  0.04162832  0.02811799]
# time came along ['I', 'in', 'life'] [ 0.79479343  0.0450066   0.02540592]
# and were a ['of', 'deputy', 'then'] [ 0.02985049  0.0217322   0.0151756 ]
# O sooner were ['were', 'son', 'hence'] [ 0.14721915  0.09373396  0.08559605]
# portial opinion ; ['thou', 'if', 'withal'] [ 0.20935763  0.20725487  0.06397219]
# us fair , ['I', 'staves', 'over'] [ 0.2044806   0.03360699  0.03099701]
# thine eyes : ['are', 'not', 'mine'] [ 0.43521044  0.13744405  0.05374916]
# that adders as ['are', 'as', 'I'] [  9.98200893e-01   7.76857371e-04   3.27766931e-04]
# my bond ; ['shall', 'And', "'"] [ 0.47088662  0.37663707  0.04277851]
# your very crimson ['love', 'for', "'"] [ 0.3332434   0.11836337  0.07759044]
# doth give his ['from', 'thy', 'mischief'] [ 0.1419902   0.05174255  0.04350591]
# I pray thee [',', 'and', 'in'] [ 0.63830703  0.1491534   0.0208672 ]
# to be possess ["'", ',', 'of'] [ 0.97426039  0.00871826  0.00168325]
# As on thy ['grace', 'I', 'villain'] [ 0.08802488  0.03075693  0.02590775]
# highness knows , ['to', 'Where', 'you'] [ 0.64312768  0.14691122  0.02687955]
# he must outlive [',', 'To', '.'] [ 0.57051945  0.05493561  0.03827279]
# my Caesar ; ['a', 'good', "'"] [ 0.20154689  0.0802168   0.0602808 ]
# something since they ['love', 'becomes', 'are'] [ 0.27729779  0.13510421  0.10864814]
# an I see ['see', 'the', 'would'] [ 0.10561908  0.07876166  0.05806582]
# dinner if every ['king?', 'every', 'the'] [ 0.81918192  0.04043676  0.01204907]
# the prince they ['I', 'do', 'If'] [ 0.45828861  0.07499057  0.0688929 ]
# , nor Butly ['my', 'I', "'"] [ 0.27669871  0.22187486  0.11074109]
# therefore queen . ['JOHN', 'often', 'I'] [ 0.09381323  0.06928658  0.06899822]
# ; If I ['be', 'will', 'was'] [ 0.33538449  0.22806676  0.03309593]
# : A thousand ['are', 'not', 'on'] [ 0.22838053  0.06501629  0.06407848]
# thee : let ['be', 'great', 'are'] [ 0.219182    0.05779056  0.05437745]
# part for gage [',', ':', '.'] [ 0.94349539  0.03832854  0.00555765]
# some master alike [':', '.', 'my'] [ 0.42099836  0.22731787  0.05860111]
# May let her ['her', 'respect', 'ears'] [ 0.5946154   0.08349445  0.04264739]
# This number well ["'", 'let', 'excellent'] [ 0.48259267  0.22001997  0.05872133]
# I am Clifford [',', ';', 'of'] [ 0.86550808  0.01606857  0.01060893]
# man were like ['a', 'for', '-'] [ 0.63737017  0.0571351   0.03363224]
# and your children ["'", 'to', 'a'] [ 0.21822213  0.20968443  0.05425201]
# Shour ' d ['d', "'", 'Give'] [ 0.95032144  0.03574916  0.00133223]
# it , And ['I', "'", 'man'] [ 0.19315167  0.040242    0.02650455]
# It pleaseth it ['than', 'it', 'more'] [ 0.62736207  0.32778901  0.00382619]
# arm my purchase [',', 'night', '-'] [ 0.85817772  0.05404596  0.03005945]
# not from loves [',', 'to', "'"] [ 0.37229842  0.07582045  0.06091766]
# nature And Hero ['do', 'I', 'they'] [ 0.28128678  0.27412742  0.13096727]
# I thoughts it [',', "'", '.'] [ 0.17737724  0.09040632  0.08847784]
# to be sell [':', "'", 'by'] [ 0.2378497   0.17729039  0.15400685]
# : True , ['O', 'our', 'a'] [ 0.25417286  0.21413872  0.09464391]
# let them suffer [';', '.', '!'] [ 0.10971364  0.10683129  0.08606325]
# well ; and ['it', 'morrow', 'is'] [ 0.14477077  0.06450581  0.04736256]
# fumbled I beseeming ['beseeming', 'to', 'a'] [ 0.94259977  0.01667756  0.00976347]
# Murderer : There ["'", 'is', 'body'] [ 0.97775638  0.00640797  0.00196188]
# of the court ['I', '.', 'shall'] [ 0.29117155  0.06806596  0.03593944]
# it begg ' ['upon', "'", 'd'] [ 0.79107016  0.20153242  0.00200975]
# : Where is ['not', 'a', 'was'] [ 0.57127196  0.15348077  0.02018309]
# disable new marriage ['marriage', '-', ';'] [ 0.91080648  0.04822846  0.0162627 ]
# wars , while ['eats', 'shall', 'Had'] [ 0.79301465  0.09195109  0.06875353]
# pound : I ['I', ':', 'think'] [  9.97949421e-01   1.28561584e-03   8.51924051e-05]
# my song till ['you', 'he', 'but'] [ 0.28440243  0.1341902   0.08069903]
# gone are so ['TROILUS', 'sir', 'death'] [ 0.44218311  0.16405071  0.04975732]
# daughter and to ['as', 'which', 'wedded'] [ 0.1575405   0.08319777  0.06535875]
# - not by ['I', 'O', 'But'] [ 0.0750083   0.05445645  0.0525915 ]
# ; Upon our ['we', 'their', 'will'] [ 0.08294198  0.07505499  0.05691292]
# I had rather ['not', 'the', ','] [ 0.24025249  0.05310266  0.0530218 ]
# OTHELLO : Give ['the', 'a', "'"] [ 0.39154762  0.33657402  0.17405602]
# their strength without ['QUICKLY', 'DEMETRIUS', 'add'] [ 0.16091113  0.06064032  0.04699553]
# by a write [',', "'", 'thou'] [ 0.62490726  0.17646267  0.03115057]
# thou never kill ["'", 'distracting', 'nor'] [ 0.50251442  0.04149005  0.02899566]
# fortune to him ['.', ':', ';'] [ 0.55524284  0.0380773   0.03300494]
# bosom is safe ['death', '!', 'he'] [ 0.50907087  0.04790602  0.04313255]
# desert , That ['That', 'I', 'have'] [ 0.9849112   0.00961757  0.00105751]
# ' d in ['the', 'this', 'his'] [ 0.22020823  0.08573617  0.05969986]
# so much worth ['to', "'", ';'] [ 0.6467101   0.17317054  0.02379934]
# sure ; To ['your', 'To', 'find'] [ 0.13206738  0.10076375  0.07691941]
# brain , The ['The', 'sea', 'of'] [  9.93314922e-01   1.18681847e-03   8.53147416e-04]
# not suffice more ['Equinius', 'more', 'then'] [ 0.69960755  0.10040601  0.02829717]
# Where ' s ['contrary', 'hear', 'a'] [ 0.23334669  0.15069097  0.14369753]
# right portial opinion ['opinion', 'thou', 'desire'] [  9.93427157e-01   1.17776264e-03   5.31029887e-04]
# fair eyes , ['slow', 'not', 'Wherefore'] [ 0.09632509  0.06153079  0.03891939]
# done all that ['we', 'that', 'and'] [ 0.21501017  0.1159749   0.07589705]
# gentleman . EMILIA [':', 'So', 'We'] [  9.99768674e-01   4.61138334e-05   2.65098315e-05]
# the passage of ['are', 'my', 'sweetest'] [ 0.14715651  0.10862972  0.09626969]
# for an innocent ['As', ':', 'is'] [ 0.11771205  0.0923142   0.08391403]
# Be here in ['the', 'call', 'remember'] [ 0.65690941  0.03535348  0.01951344]
# . VOLUMNIA : ['Think', 'I', 'gentlemen'] [ 0.72893685  0.03612195  0.02059498]
# tis fled , ['thee', '.', 'lie'] [ 0.1641994   0.07852562  0.05331211]
# ; splitted from ['Caesar', 'from', 'not'] [ 0.96028036  0.00459228  0.0045352 ]
# in language time ['.', 'hope', ';'] [ 0.78673476  0.02636955  0.02118291]
# yourself , where ['lord', 'to', 'lusty'] [ 0.34515789  0.03278087  0.02795544]
# icfortune up , ['that', 'up', 'Thou'] [ 0.29411668  0.16160975  0.15087955]
# no host ; [';', 'to', 'a'] [ 0.45811486  0.43584621  0.0422461 ]
# the office in ['head', 'in', 'from'] [ 0.7047469   0.22611585  0.01165415]
# are you? no [':', 'OF', 'that'] [ 0.10424421  0.07379234  0.07042544]
# my lord ; ['I', 'thus', 'but'] [ 0.64463234  0.02461695  0.01397733]
# Comest thou our ['our', 'thou', 'seven'] [  9.97561574e-01   1.64808205e-03   2.08771162e-04]
# cold to be ['your', "'", 'thing'] [ 0.36224622  0.18348782  0.15911323]
# It ' s ['great', 'a', 'the'] [ 0.19613148  0.12535487  0.07081091]
# Of Alexander lives ['lives', '.', 'and'] [ 0.59625393  0.28170872  0.05634722]
# a king is ['hath', '-', 'Second'] [ 0.11811578  0.06990277  0.06016426]
# s remedy , ['Rome', 'I', 'king'] [ 0.77675641  0.13591458  0.01010724]
# it . CYMBELINE [':', 'I', 'point'] [ 0.35622221  0.1658942   0.02344376]
# good morrow , ['for', 'I', 'what'] [ 0.63959938  0.06118319  0.0335356 ]
# as is your ['Lord', "'", 'hell'] [ 0.02691454  0.02566452  0.02207926]
# , sometime to ['Messala', 'this', 'as'] [ 0.21360268  0.1309137   0.06315751]
# , to be ['I', 'your', "'"] [ 0.04566522  0.03479915  0.02391137]
# can swear even ['to', 'for', 'that'] [ 0.45841616  0.14563079  0.06386259]

# %%
def sentence_generator(session, length, start_words):
    def matrix_to_words(mat):
        words = []
        for i in range(mat.shape[0]):
            word_idx = mat[i,:].argmax()
            word = rev_dict[word_idx]
            words.append(word)
        return ' '.join(words)
    pre_length = len(start_words)
    length_to_generate = length - pre_length
    words = np.zeros([length, vocab_size])

    for i in range(pre_length):
        words[i][start_words[i]] = 1

    for i in range(pre_length, length):
        x = np.reshape(words[i-n_input:i,:], [1, n_input, vocab_size])
        p = predict(session, x)
        # represent_x_and_y(x, p)
        pred = predict(session, x)[0]
        words[i] = pred
    words_text = matrix_to_words(words)
    print(words_text)

# %%
sentence_generator(session, 100, [dictionary[i] for i in 'Z M N'.split(' ')])

# %%
raw, w2v_model = read_data('belling_the_cat.txt')
# Out:
# ['suffolk' ':' '\n' ..., '\n' 'brutus' '\n'] (2347,)

# %%
x_train
# Out:
# array([[[ -1.39600992e-01,   1.70090467e-01,  -1.09117841e-02, ...,
#           -5.81735492e-01,  -2.85451323e-01,  -3.19034994e-01],
#         [ -1.52070625e-02,   9.17999167e-03,   6.82297442e-03, ...,
#           -3.30649950e-02,  -1.43043520e-02,  -3.84610333e-03],
#         [ -1.85123682e-01,   1.92965448e-01,  -2.02680733e-02, ...,
#           -6.80584490e-01,  -3.46160322e-01,  -3.65011156e-01]],
#
#        [[ -2.42117330e-01,   2.73815811e-01,  -1.49040744e-02, ...,
#           -9.51315761e-01,  -4.66206580e-01,  -5.12049735e-01],
#         [  2.90360535e-03,   1.20017724e-02,  -8.38095229e-03, ...,
#           -2.84511615e-02,  -7.92866852e-03,  -5.90040069e-03],
#         [ -2.19042078e-01,   2.48720586e-01,  -3.13709117e-03, ...,
#           -8.74254346e-01,  -4.25594896e-01,  -4.71629828e-01]],
#
#        [[ -7.40444139e-02,   8.66002142e-02,  -1.34397135e-03, ...,
#           -3.17642629e-01,  -1.59537703e-01,  -1.60744488e-01],
#         [ -1.48574010e-01,   1.86885625e-01,  -7.39162555e-03, ...,
#           -6.06652737e-01,  -3.09005231e-01,  -3.32773983e-01],
#         [ -1.50039479e-01,   1.73990920e-01,  -1.57738701e-02, ...,
#           -5.57783961e-01,  -2.68346965e-01,  -2.90769339e-01]],
#
#        ...,
#        [[ -2.14361940e-02,   3.16214114e-02,  -5.44744497e-03, ...,
#           -9.77701098e-02,  -6.06504455e-02,  -6.16258830e-02],
#         [ -2.42117330e-01,   2.73815811e-01,  -1.49040744e-02, ...,
#           -9.51315761e-01,  -4.66206580e-01,  -5.12049735e-01],
#         [ -7.31089413e-02,   8.47857445e-02,  -7.83373043e-03, ...,
#           -2.90396631e-01,  -1.44707337e-01,  -1.56612188e-01]],
#
#        [[ -8.00554380e-02,   8.59523937e-02,   5.22720907e-03, ...,
#           -3.11817765e-01,  -1.60989821e-01,  -1.61649764e-01],
#         [ -1.82206556e-01,   2.24572882e-01,  -2.37209606e-03, ...,
#           -7.31100142e-01,  -3.74792039e-01,  -4.02052730e-01],
#         [ -1.10276435e-02,   6.16040634e-05,   1.27914373e-03, ...,
#           -1.33117102e-02,  -6.29982725e-03,  -1.14204288e-02]],
#
#        [[ -1.63519025e-01,   1.99329942e-01,  -1.35300867e-03, ...,
#           -6.29925013e-01,  -3.11186403e-01,  -3.33209693e-01],
#         [  5.41719096e-03,   5.33264736e-03,  -1.64896098e-03, ...,
#           -8.34194105e-03,  -8.16456228e-03,  -5.52207837e-03],
#         [ -7.19495444e-03,  -2.75426987e-03,  -1.41210633e-03, ...,
#           -7.00413343e-03,   7.69415498e-03,   5.16434712e-03]]])

# %%
index = w2v_model.wv.vocab['word'].index
word = w2v_model.wv.index2word[index]

# %%
word
# Out:
# 'word'
